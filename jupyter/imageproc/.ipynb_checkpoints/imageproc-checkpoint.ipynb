# %%
import glob
import math
import os
import sys

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import skimage.measure as ski
import re

from pathlib import Path
cur_dir = Path().resolve()
sys.path.append(str(cur_dir) + "/module")

# %%
class IniFileReader:
    """Iniファイル読み込みクラス"""
    def __init__(self, filename):
        self.filename = filename
    
    def read(self):
        f = open(self.filename)
        self.params_list = f.readlines()
        f.close()
        self.params_list = [re.match("(.+)=(.+)", line) for line in self.params_list]
        self.dict = {item[1]:item[2] for item in self.params_list if item}

class ImageProcIniReader(IniFileReader):
    """画像処理Iniファイル読み込みクラス"""

    def deploy(self):
        if (len(self.dict) != 0):
            self.x = self.dict['x']
            self.y = self.dict['y']
            self.thresh = self.dict['threshold']
            self.lena_img_path = self.dict['LenaImagePath']
            self.cameraman_img_path = self.dict['CameramanImagePath']
            self.result_hist_dir = self.dict['ResultHistogramDir']

# %%
"""Image Processing"""

#エッジ検出
def detect_edges(image_path):
    """入力画像のエッジを検出する

    Parameters
    ----------
    image_path : str
        入力画像のパス

    Returns
    -------
    edges
        エッジ検出後の画像
    """
    image = cv2.imread(image_path, cv2.COLOR_BGR2RGB)
    edges = cv2.Canny(image, 100, 200)
    return edges


def plot_histogram(image, title='Image Histgram'):
    """画像のヒストグラムを表示"""

    # 画像のヒストグラムを計算
    histogram, bins = np.histogram(image.flatten(), bins=256, range=[0, 256])

    # ヒストグラムをプロット
    plt.figure()
    plt.title(title)
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.plot(histogram, color='blue')
    plt.xlim([0, 256])
    plt.show()

def percentile_thresholding(img, p=95):
    """p-タイル法による2値化閾値算出

    Parameters
    ----------
    img : Any
        入力画像
        2値化画像
    p : int, optional
        画像占有率, by default 95

    Returns
    -------
    bin_img : Any
    """
    # 画像のピクセル値を1次元配列に変換
    pixels = img.flatten()

    # pパーセンタイルの計算
    bin_threshold = np.percentile(pixels, p)

    bin_img = np.where(img >= bin_threshold, 255, 0).astype(np.uint8)

    return bin_img
    
def otsu_threshold(image):
    # 画像のヒストグラムを計算
    histogram, _ = np.histogram(image.flatten(), bins=256, range=[0, 256])

    # 画像全体のピクセル数
    total_pixels = image.shape[0] * image.shape[1]

    # 初期値
    best_threshold = 0
    best_variance = 0

    # 閾値の評価
    for threshold in range(256):
        # クラス1のピクセル数とクラス2のピクセル数を計算
        class1_pixels = np.sum(histogram[:threshold])
        class2_pixels = np.sum(histogram[threshold:])

        # クラス1とクラス2の平均値を計算
        class1_mean = np.sum(histogram[:threshold] * np.arange(threshold)) / class1_pixels
        class2_mean = np.sum(histogram[threshold:] * np.arange(threshold, 256)) / class2_pixels

        # クラス1とクラス2の分散を計算
        class1_variance = np.sum(((np.arange(threshold) - class1_mean) ** 2) * histogram[:threshold]) / class1_pixels
        class2_variance = np.sum(((np.arange(threshold, 256) - class2_mean) ** 2) * histogram[threshold:]) / class2_pixels

        # クラス内分散とクラス間分散の合計を計算
        within_class_variance = (class1_pixels / total_pixels) * class1_variance + (class2_pixels / total_pixels) * class2_variance
        between_class_variance = (class1_pixels / total_pixels) * (class2_pixels / total_pixels) * ((class1_mean - class2_mean) ** 2)

        # クラス間分散が最大の場合、閾値を更新
        if between_class_variance > best_variance:
            best_variance = between_class_variance
            best_threshold = threshold

    return best_threshold

def dog_filter(image, sigma1, sigma2):
    # 画像をグレースケールに変換
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # ガウシアンフィルタを適用して画像を平滑化
    smoothed1 = cv2.GaussianBlur(gray_image, (0, 0), sigmaX=sigma1)
    smoothed2 = cv2.GaussianBlur(gray_image, (0, 0), sigmaX=sigma2)
    
    # DoG画像を計算
    dog_image = np.subtract(smoothed1, smoothed2)
    
    return dog_image

# %%
#load ini file
filename = 'imageproc.ini'
inireader = ImageProcIniReader(filename)
inireader.read()
inireader.deploy()

#lena画像パス
lena_path = inireader.lena_img_path

img = cv2.imread(lena_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# fig,aixs = plt.subplot(1,1)
kernel = np.ones((3,3))
img_ero = cv2.erode(img, kernel, iterations=2)
dst = cv2.dilate(img_ero, kernel, iterations=2)
edges = detect_edges(lena_path)

#グラフ表示領域
fig = plt.figure()

#グラフを追加する
ax_closing = fig.add_subplot(1, 2, 1)
ax_edges_canny = fig.add_subplot(1, 2, 2)


ax_closing.imshow(dst)
ax_edges_canny.imshow(edges)
plt.show()

# %%
img = cv2.imread(lena_path, cv2.IMREAD_ANYDEPTH)
bin_threshold = otsu_threshold(img)
print(bin_threshold)
ret, img = cv2.threshold(img, bin_threshold, 255, cv2.THRESH_BINARY)
fig2 = plt.figure()
ax_otsu_lena = fig2.add_subplot(1, 2, 1)
ax_otsu_lena.imshow(img)
plt.show
# Out:
# 125
# c:\Users\kaito\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:80: RuntimeWarning: invalid value encountered in longlong_scalars
# c:\Users\kaito\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:84: RuntimeWarning: invalid value encountered in double_scalars
# c:\Users\kaito\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:81: RuntimeWarning: invalid value encountered in longlong_scalars
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
glay_lena = cv2.imread(lena_path, cv2.COLOR_RGB2GRAY)
plot_histogram(glay_lena, 'Lena Image')

# %%
#Math Function

#二乗平方平均
def RMS(numbers):
    """Calculate RMS(root mean square)"""
    squared_sum = sum(x ** 2 for x in numbers)
    mean_squared = squared_sum / len(numbers)
    rms = math.sqrt(mean_squared), 3
    return rms

# 離散フーリエ変換
def DFT(signal):
    N = len(signal)
    n = np.arange(N)
    k = n.reshape((N, 1))
    e = np.exp(-2j * np.pi * k * n / N)
    transformed_signal = np.dot(e, signal)
    return transformed_signal

#楕円率(長径に対する短径の比)
def calc_elipicity(long_a, short_b, ratio=3):
    return round(short_b/long_a, ratio)

#2枚の画像を比較してRMSを算出する
def compare_img_RMS(img_src, img_ref, height=512, width=512):
    diff = cv2.absdiff(img_src, img_ref)
    sum = cv2.add(img_src, img_ref)

    tmp_list = []
    for y in range(height):
        for x in range(width):
             tmp_list.append(diff[y, x] / sum[y,x])
    
    result = RMS(tmp_list)
    return result

# %% [markdown]
# ## 離散フーリエ変換(DFT)

# %%
# 入力信号の作成
signal = np.array([0, 1, 2, 3, 4, 5, 6, 7])

# 離散フーリエ変換の実行
transformed_signal = DFT(signal)

# 結果のグラフ表示
plt.plot(np.abs(transformed_signal))
plt.title('Discrete Fourier Transform')
plt.xlabel('Frequency[Hz]')
plt.ylabel('Volt[V]')
plt.show()

# %% [markdown]
# # Image read

# %%
#load ini file
filename = 'imageproc.ini'
inireader = ImageProcIniReader(filename)
inireader.read()
inireader.deploy()
img = cv2.imread(inireader.cameraman_img_path, cv2.IMREAD_ANYDEPTH)
plt.imshow(img, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # Display Histogram

# %%
data = img.reshape(-1)
plt.hist(data, bins=256)
plt.xlim(0, 256)
plt.ylabel('Frequency')
plt.xlabel('Pixel Value')
plt.savefig(inireader.result_hist_dir + '\\cameraman_hist.png')
plt.show()

# %% [markdown]
# # K-means

# %%
labels = np.random.randint(0, 2, data.shape[0])
epsilon = 1
clasifytimes = 1000

m0_old = -np.inf
m1_old = np.inf

for i in range(clasifytimes):
    #calculate mean value of each calss
    m0 = data[labels==0].mean()
    m1 = data[labels==1].mean()
    labels[np.abs(data - m0) < np.abs(data - m1)] = 0
    labels[np.abs(data - m0) > np.abs(data - m1)] = 1
    if np.abs(m0 - m0_old) + np.abs(m1 - m1_old) < epsilon:
        break
    m0_old = m0
    m1_old = m1

kmeans_th = np.minimum(data[labels == 0].max(), data[labels == 1].max())
print('K-means mehod threshold = ' + str(kmeans_th))
plt.hist(data[labels==0], bins=128, label='Class0')
plt.hist(data[labels==1], bins=128, label='Class1')
plt.scatter([kmeans_th], [0], s = 50, marker='*', color='r', label='Optimal={0:d}'.format(kmeans_th))
plt.legend()
plt.title('K-means method')
plt.ylabel('Frequency')
plt.xlabel('Pixel value')
plt.savefig(inireader.result_hist_dir + '\\hist_kmeans.png')
plt.show()
# Out:
# K-means mehod threshold = 88

# %%
threshold = kmeans_th

img_thresh = np.array(img > threshold)
plt.imshow(img_thresh, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # Line Profile
#
# ```
# >>> x = np.array([[1, 1, 1, 2, 2, 2]])
# >>> img = np.vstack([np.zeros_like(x), x, x, x, np.zeros_like(x)])
# >>> img
# array([[0, 0, 0, 0, 0, 0],
#        [1, 1, 1, 2, 2, 2],
#        [1, 1, 1, 2, 2, 2],
#        [1, 1, 1, 2, 2, 2],
#        [0, 0, 0, 0, 0, 0]])
# >>> profile_line(img, (2, 1), (2, 4))
# array([1., 1., 2., 2.])
# >>> profile_line(img, (1, 0), (1, 6), cval=4)
# array([1., 1., 1., 2., 2., 2., 2.])
# ```

# %%
path_list = glob.glob(r'C:\work\Pyhton\image\*.png')

img_list = [cv2.imread(path, cv2.IMREAD_GRAYSCALE) for path in path_list]

#vertical
start_v = (0, 127)
end_v = (255, 127)
#horizontal
start_h = (127, 0)
end_h = (127, 255)

fig, axes = plt.subplots(2, 4, figsize=(12, 6))
for i in range(2):
    for j in range(4):
        axes[i][j].set_title('image')
        if(i == 0):
            axes[i][j].imshow(img_list[j], cmap='gray')
            axes[i][j].plot([start_v[1], end_v[1]], [start_v[0], end_v[0]], 'r-', lw=2)
            axes[i][j].plot([start_h[1], end_h[1]], [start_h[0], end_h[0]], 'b-', lw=2)
        if(i == 1):
            axes[i][j].imshow(img_list[j+4], cmap='gray')
            axes[i][j].plot([start_v[1], end_v[1]], [start_v[0], end_v[0]], 'r-', lw=2)
            axes[i][j].plot([start_h[1], end_h[1]], [start_h[0], end_h[0]], 'b-', lw=2)
        if(i == 2):
            axes[i][j].imshow(img_list[j+8], cmap='gray')
            axes[i][j].plot([start_v[1], end_v[1]], [start_v[0], end_v[0]], 'r-', lw=2)
            axes[i][j].plot([start_h[1], end_h[1]], [start_h[0], end_h[0]], 'b-', lw=2)

# %%
profile_v_list = [ski.profile_line(img_list[i], start_v, end_v, linewidth=1) for i in range(8)]
profile_h_list = [ski.profile_line(img_list[i], start_h, end_h, linewidth=1) for i in range(8)]
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
for i in range(2):
    for j in range(4):
        axes[i][j].set_title('image')
        if(i == 0):
            axes[i][j].plot(profile_v_list[j])
            axes[i][j].plot(profile_h_list[j])
        if(i == 1):
            axes[i][j].plot(profile_v_list[j+4])
            axes[i][j].plot(profile_h_list[j+4])

# %%
from PIL import Image

# データを埋め込む関数
def embed_data(image_path, data, output_path):
    img = Image.open(image_path)

    # データをバイト列に変換
    data_bytes = data.encode('utf-8')
    data_length = len(data_bytes)

    # データ長を画像のピクセル値として埋め込む（R、G、Bの下位2ビットずつ使用）
    pixels = img.load()
    width, height = img.size
    pixel_index = 0
    for i in range(height):
        for j in range(width):
            if pixel_index < data_length:
                r, g, b = pixels[j, i]
                r = (r & 0xFC) | ((data_bytes[pixel_index] >> 6) & 0x03)
                g = (g & 0xFC) | ((data_bytes[pixel_index] >> 4) & 0x03)
                b = (b & 0xFC) | ((data_bytes[pixel_index] >> 2) & 0x03)
                pixels[j, i] = (r, g, b)
                pixel_index += 1
            else:
                break

    img.save(output_path)

# データを抽出する関数
def extract_data(image_path):
    img = Image.open(image_path)

    data_bytes = bytearray()
    pixels = img.load()
    width, height = img.size
    pixel_index = 0
    while pixel_index < (width * height):
        r, g, b = pixels[pixel_index % width, pixel_index // width]
        data_bytes.append(((r & 0x03) << 6) | ((g & 0x03) << 4) | ((b & 0x03) << 2))
        pixel_index += 1

    extracted_data = data_bytes.decode('utf-8')
    return extracted_data

# データを埋め込む
embed_data('../../image//kanji_ref.png', '秘密のメッセージ', '../../image/kanji_embed.png')

# データを抽出する
extracted_data = extract_data('output.png')
print("抽出されたデータ:", extracted_data)
